# %% [markdown]
# # Agentic summarization with LangGraph
#
# Evolve the summarization workflow into an agentic system with LangGraph: explicit state management and conditional branching so the pipeline adapts, scales, and lays groundwork for autonomous agents.
